# %%
import cv2
import skimage as ski
import matplotlib.pyplot as plt

# %%
img=cv2.imread('contact-img.png')
cv2.imshow('',img)
cv2.waitKey(1000)
cv2.destroyAllWindows()

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (392, 519, 3)

# %%
img
# Out:
# array([[[ 76, 112,  71],
#         [ 76, 112,  71],
#         [ 76, 112,  71],
#         ...,
#         [ 76, 112,  71],
#         [ 76, 112,  71],
#         [ 76, 112,  71]],
#
#        [[ 76, 112,  71],
#         [ 76, 112,  71],
#         [ 76, 112,  71],
#         ...,
#         [ 76, 112,  71],
#         [ 76, 112,  71],
#         [ 76, 112,  71]],
#
#        [[ 76, 112,  71],
#         [ 76, 112,  71],
#         [ 76, 112,  71],
#         ...,
#         [ 76, 112,  71],
#         [ 76, 112,  71],
#         [ 76, 112,  71]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
img1=plt.imread('contact-img.png')
plt.imshow(img1)
